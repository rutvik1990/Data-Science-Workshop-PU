# %% [markdown]
# <a href="https://colab.research.google.com/github/rutvik1990/Data-Science-Workshop-PU/blob/main/%20Data_Analysis_Notebooks/Notes_Visualization/Data_Visualization_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
import numpy as np 

data = np.random.randn(10000) # Generate Some Data 
 
fig = Figure() #Create a Figure  
canvas = FigureCanvas(fig)  # Attach a Canvas 
# Create A plot on Figure and get the axes  
ax = fig.add_subplot(111) 
ax.hist(data, 100) # Draw chart using axes  
ax.set_title("Normal Distribution with $\mu=0 and \sigma=1$") # Add title to chart 
fig.savefig("hist_demo.png")

# %%
import matplotlib.pyplot as plt 
import numpy as np 
 
data = np.random.randn(10000) 
plt.hist(data,100) 
plt.title("Normal Distribution") 
plt.savefig("HistDemo.png") 
plt.show()

# %%
X=np.linspace(-np.pi,np.pi,250,endpoint=True) 
C,S=np.cos(X),np.sin(X) 
plt.title("Sinosudal Plot") 
plt.xlabel("Angle in Radian") 
plt.ylabel("Sine") 
plt.plot(X,C,'ro',X,S,'b')

# %%
import matplotlib.pyplot as plt
import numpy as np
X=np.arange(10)
Y1=X
Y2=X**2
Y3=X**3
#Optional- by default it will take the active Figure
plt.figure(1)
plt.subplot(311)
plt.title("Linear")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(X,Y1,'ro')
plt.subplot(312)
plt.title("Square")
plt.xlabel("X")
plt.ylabel("Y^2")
plt.subplot(313)
plt.plot(X,Y2,'bs')

# %%
import matplotlib.pyplot as plt
plt.title("Preference")
frac=[10,35,45,10]  
labels=["A",'B','C','D']
plt.pie(x=frac, labels=labels)
plt.legend()

# %%
plt.title("Bar Chart") 
 
frac=[15,30,45,10] 
cat=["Pre-school",'PG','UG','PhD'] 
plt.subplot(211)
plt.bar(x=cat, height=frac, color=['red','green','blue','black']) 
plt.subplot(212)
plt.barh(y=cat, width=frac, color=['red','green','blue','black'])
# Out:
# <BarContainer object of 4 artists>

# %%
mu, sigma=100,15 
data = mu+sigma*np.random.randn(100) 
 
plt.hist(data,50,facecolor='g',edgecolor='k',alpha=0.75) 
plt.text(100,7,r'$\mu=100,\sigma=15$') 
plt.show()

# %%
year=[2000,2001,2002,2003,2004,2005] 
itemA=[100,90,120,200,100,90] 
itemB=[120,100,90,120,160,90] 
#Color 'red', marker 'circle', line type 'dashed'
plt.subplot(211) 
plt.plot(year,itemA,'ro--') 
plt.subplot(212)
plt.plot(year,itemA,'ro--',year,itemB,'gs-') 
plt.legend(['itemA','itemB']) 
#plt.grid()   
plt.show()

# %%
year=[2000,2001,2002,2003,2004,2005] 
itemA=[100,90,120,200,100,90] 
itemB=[120,100,90,120,160,90] 
plt.subplot(221)
plt.fill_between(year, min(itemA),itemA, alpha=0.5) 
plt.subplot(222)
plt.fill_between(year, min(itemA),itemA, alpha=0.5) 
plt.fill_between(year, min(itemB),itemB, alpha=0.5) 
plt.show()

# %%
year=[2000,2001,2002,2003,2004,2005] 
itemA=[100,90,120,200,100,90] 
itemB=[120,100,90,120,160,90] 
plt.stackplot(year, itemA, itemB, alpha=0.5) 
plt.show()

# %%
XA= np.random.uniform(size=10) 
YA= np.random.uniform(size=10) 
XB= np.random.uniform(size=10) 
YB= np.random.uniform(size=10) 
plt.scatter(XA,YA,marker='o') 
plt.scatter(XB,YB,marker='s') 
plt.show()

# %%
XA
# Out:
# array([0.83329028, 0.88719994, 0.8366985 , 0.50173864, 0.0161832 ,
#        0.71564728, 0.62453592, 0.71226034, 0.96660414, 0.33309213])

# %%
def f(x,y): 
    return (x**2+2*x*y+y**2) 
x=np.linspace(-1,1,256) 
y=np.linspace(-1,1,256) 
X,Y= np.meshgrid(x,y) 
plt.contourf(X,Y,f(X,Y),cmap='jet')

# %%
var1= np.random.randint(low=0,high=10,size=10) 
var2= np.random.randint(low=0,high=10,size=10) 
var3= np.random.randint(low=0,high=10,size=10) 
plt.title("Boxplot") 
plt.boxplot([var1, var2, var3])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f9a1e8acd90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9a1e3b1c50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9a1e69c750>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9a1e6342d0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9a1e78b350>,
# ...
#   <matplotlib.lines.Line2D at 0x7f9a1e6955d0>]}

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
 
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer") 
 
wc= WordCloud(width=680,height=680,margin=0).generate(text)
plt.imshow(wc, interpolation='bilinear') 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
data = pd.Series({'IND':8929,'PRC':7823,'BRZ':6435, 'UK':1023,'US':2003})                   
plt.subplot(211)
data.plot(kind='pie')
plt.subplot(212)
data.plot(kind='bar') 
plt.title("Canada Immigrants") 
plt.legend()

# %%
#period referes to number of days starting from 1/1/2000
ts = pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000', periods=1000)) 
ts = ts.cumsum() 
ts.plot() 
 
df = pd.DataFrame(np.random.randn(1000, 4),index=ts.index, columns=list('ABCD')) 
df = df.cumsum() 
df.plot()

# %%
df.iloc[5] #i.e. fifth row 
#plt.subplot(441)
df.iloc[5].plot(kind='bar') 
#plt.subplot(442)
#df.plot.bar() 
#plt.subplot(443)
df.plot.hist(alpha=0.5) 
#plt.subplot(444)
df.plot.box()

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd']) 
df.plot.area(); #df.plot(kind='area')
df.plot.area(stacked=False);

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd']) 
df.plot.scatter(x='a',y='b',c='c', s=50); 
df.plot.scatter(x='a',y='b',s=df['c']*200);

# %%
import seaborn as sns
from pandas.plotting import scatter_matrix 
iris = sns.load_dataset('iris') 
#parallel_coordinates(iris,'species') 
#df = pd.DataFrame(np.random.rand(100, 4), columns=['a', 'b', 'c', 'd']) 
scatter_matrix(iris)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9a0f1fca90>,
# ...
#       dtype=object)

# %%
import seaborn as sns
from pandas.plotting import parallel_coordinates  
iris = sns.load_dataset('iris') 
parallel_coordinates(iris,'species')

# %%
import seaborn as sns
#load sample data 
data = sns.load_dataset('tips') 
#set default theme 
sns.set()
sns.relplot(x="total_bill", y="tip", col="time", hue="smoker", style="smoker", size="size", data=data)

# %%
sns.lmplot(x="total_bill", y="tip", col="time", hue="smoker", data=data)

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="swarm", data=data) 
sns.catplot(x="day", y="total_bill", hue="smoker", kind="violin", data=data) 
sns.catplot(x="day", y="total_bill", kind="box", data=data)

# %%
sns.pairplot(data=iris, hue="species")

# %%
import folium 
m = folium.Map(location=[22.3, 73.18]) 
m.save("map.html")

# %%
folium.Marker(location=[22.3, 73.18],popup="Vadodara", icon=folium.Icon('green')).add_to(m) 
folium.CircleMarker(radius=100, location=[22.3, 73.18], popup='The Waterfront', color='crimson', fill=True, fill_color='crimson').add_to(m) 
m.save("map2.html")

# %%
import numpy as np 
   
from bokeh.io import curdoc 
from bokeh.layouts import row, widgetbox, column
from bokeh.models import ColumnDataSource 
from bokeh.models.widgets import Slider, TextInput 
from bokeh.plotting import figure 
 
#Step 1 Generate Data
N = 200
x = np.linspace(0, 4*np.pi, N) 
y = np.sin(x) 
# Data source suitable to serve in webapp using http 
source = ColumnDataSource(data=dict(x=x, y=y)) 

#Step 2 Create Plot
plot = figure(plot_height=400, plot_width=400, title="my sine wave", tools="crosshair,pan,reset,save,wheel_zoom", x_range=[0, 4*np.pi], y_range=[-2.5, 2.5]) 
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

#Step 3 Add UI Widget that controls plot
text = TextInput(title="title", value='my sine wave') 
offset = Slider(title="offset", value=0.0, start=-5.0, end=5.0, step=0.1) 
amplitude = Slider(title="amplitude", value=1.0, start=-5.0, end=5.0, step=0.1) 
phase = Slider(title="phase", value=0.0, start=0.0, end=2*np.pi) 
freq = Slider(title="frequency", value=1.0, start=0.1, end=5.1, step=0.1) 

#Step 4 Add Event Callback
def update_title(attrname, old, new): 
    plot.title.text = text.value   
text.on_change('value', update_title) 
   
def update_data(attrname, old, new): 
  # Get the current slider values 
    a = amplitude.value 
    b= offset.value 
    w = phase.value 
    k = freq.value 
  # Generate the new curve 
    x = np.linspace(0, 4*np.pi, N) 
    y = a*np.sin(k*x + w) + b 
    source.data = dict(x=x, y=y) 
   
for w in [offset, amplitude, phase, freq]: 
  w.on_change('value', update_data) 

# Step 5: Set Layout and Add Components to document 
inputs = column(text, offset, amplitude, phase, freq)

curdoc().add_root(row(inputs, plot, width=800))
curdoc().title = "Sliders"

# %%
import plotly 
import plotly.graph_objs as go 
plotly.offline.plot({"data":[go.Scatter(x=[2,4,6,8],y=[6,7,8,3])], "layout": go.Layout(title="Demo")}, auto_open=True)
# Out:
# 'temp-plot.html'

# %%
N = 100
x = np.random.rand(N) 
y = np.random.rand(N) 
colors = np.random.rand(N) 
sz = np.random.rand(N)*30 
 
fig = go.Figure() 
fig.add_scatter(x=x, y=y, mode='markers', 
                marker={'size': sz, 
                        'color': colors, 
                        'opacity': 0.6, 
                        'colorscale': 'Viridis' 
                       }); 
plotly.offline.plot(fig, auto_open=True)
# Out:
# 'temp-plot.html'

# %%
labels = ['Oxygen','Hydrogen','Carbon_Dioxide','Nitrogen']
values = [4500,2500,1053,500] 
 
trace = go.Pie(labels=labels, values=values) 
 
plotly.offline.iplot([trace])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ec03aa61-1a75-4f62-a700-ca354f002dd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ec03aa61-1a75-4f62-a700-ca354f002dd8")) {
#                     Plotly.newPlot(
#                         'ec03aa61-1a75-4f62-a700-ca354f002dd8',
# ...

# %%
trace1 = go.Scatter( 
    x=[1, 2, 3, 4], 
    y=[0, 2, 3, 5], 
    fill='tozeroy' 
) 
trace2 = go.Scatter( 
    x=[1, 2, 3, 4], 
    y=[3, 5, 1, 7], 
    fill='tonexty' 
) 
 
data = [trace1, trace2] 
plotly.offline.iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3108497f-8f5c-4d36-a224-5a1699d13884" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3108497f-8f5c-4d36-a224-5a1699d13884")) {
#                     Plotly.newPlot(
#                         '3108497f-8f5c-4d36-a224-5a1699d13884',
# ...

# %%
x=['Winter', 'Spring', 'Summer', 'Fall'] 
trace0 = dict( 
    x=x, 
    y=[40, 60, 40, 10], 
    hoverinfo='x+y', 
    mode='lines', 
    line=dict(width=0.5, 
              color='rgb(131, 90, 241)'), 
    stackgroup='one' 
) 
trace1 = dict( 
    x=x, 
    y=[20, 10, 10, 60], 
    hoverinfo='x+y', 
    mode='lines', 
    line=dict(width=0.5, 
              color='rgb(111, 231, 219)'), 
    stackgroup='one' 
) 
plotly.offline.iplot([trace0,trace1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="024bef04-7f0b-45a0-b0f7-d3f6ffe5da62" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("024bef04-7f0b-45a0-b0f7-d3f6ffe5da62")) {
#                     Plotly.newPlot(
#                         '024bef04-7f0b-45a0-b0f7-d3f6ffe5da62',
# ...
